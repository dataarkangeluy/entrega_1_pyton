# %%
#################  recursos necesarios ##############
# !pip install unidecode  # Instala sistema de codificación de caracteres



print("""Bienvenido al juego del ahorcado..!
El juego consiste en adivinar las palabras ocultas que están detrás de los cuadros blancos.
Logras la victoria si no ahorcas a tu amigo.""")


nombre=input("Cual es tu nombre?")
print(f"""
muy bien, {nombre} comencemos a jugar
""")

# Uilizar funcion para pasar 
# Ejemplo 2 en clase 9_funcion para detectar la letra

#################  inicializacion de variables ##############

peliculas=" "
tuletra=" "
contador_vidas =7



#################  Lista de peliculas ##############

# abro el archivo
with open('pelis.txt', encoding="utf-8") as f:
    mis_peliculas = f.readlines()

# cerrar el archivo
f.close() 

print(mis_peliculas)





#peliculas = ['Lo que el viento se llevó', 
#             'Avatar', 'Star Wars: Episodio IV - Una nueva esperanza', 
#             'Avengers Endgame', 
#             'Titanic', 
#             'The Sound of Music', 
#             'E.T. el extraterrestre', 
#             'Los diez mandamientos', 
#             'Doctor Zhivago', 
#             'Star Wars Episodio VII - El despertar de la Fuerza']
#
# print(len(peliculas))
#####################################################



#################  elige la pelicula al azar ##############

import random # importa el modulo random de python
def selectRandom(peliculas):
    return random.choice(peliculas)
adivinanza = selectRandom(peliculas)

print(f"La pelicula elegida para el juego es: {adivinanza} ")


#################  Ingresa tu letra  ##############    

letra = input("escriba una letra: ")

if len(letra) == 1:
    if letra in adivinanza:
        print("Es vocal")
    else:
        print("No es vocal")
else:
    print("No se puede procesar")


#################  para vidas  ##############


# hacer una funcion que dado un string

#while contador < 10:
#    if tuletra in adivinanza
#    print(contador_vidas)
#    contador_vidas+=1
#    else:
#        print(contador_vidas)
    
#####################################################    
    


# infiltrada = ["a","e","i", "y", "o", "u"]
# letra_ingresada = input("Ingrese una letra")
# remove(valor) el metodo recibe el valor que queremos borrar
# En nuestro caso queresmos remover la letra "y"
# infiltrada.remove(acertada)
# infiltrada
# letra_ingresada in [peliculas]
# Out:
# Bienvenido al juego del ahorcado..!
# El juego consiste en adivinar las palabras ocultas que están detrás de los cuadros blancos.
# Logras la victoria si no ahorcas a tu amigo.
# Cual es tu nombre?gabo
#
# muy bien, gabo comencemos a jugar
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-3c65b1137044> in <module>
#      28
#      29 # abro el archivo
# ---> 30 with open('pelis.txt', encoding="utf-8") as f:
#      31     mis_peliculas = f.readlines()
#      32
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pelis.txt'
